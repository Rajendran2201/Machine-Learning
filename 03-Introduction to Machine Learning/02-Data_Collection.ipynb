# %% [markdown]
# #Data Collection Sites
#
# 1. Kaggle
# 2. UCI Machine Learning Repository
# 3. GOogle Dataset Search

# %%
import pandas as pd

# %%
# loading dataset to pandas dtaframe

dataset = pd.read_csv('/content/boston-housing-dataset.csv')

# %%
dataset.head()
# Out:
#    Unnamed: 0     CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 0           0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1
# 1           1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2
# 2           2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2
# 3           3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3
# 4           4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3
#
#      TAX  PTRATIO       B  LSTAT  MEDV
# 0  296.0     15.3  396.90   4.98  24.0
# 1  242.0     17.8  396.90   9.14  21.6
# 2  242.0     17.8  392.83   4.03  34.7
# 3  222.0     18.7  394.63   2.94  33.4
# 4  222.0     18.7  396.90   5.33  36.2

# %%
dataset.tail()
# Out:
#      Unnamed: 0     CRIM   ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  \
# 501         501  0.06263  0.0  11.93     0  0.573  6.593  69.1  2.4786    1
# 502         502  0.04527  0.0  11.93     0  0.573  6.120  76.7  2.2875    1
# 503         503  0.06076  0.0  11.93     0  0.573  6.976  91.0  2.1675    1
# 504         504  0.10959  0.0  11.93     0  0.573  6.794  89.3  2.3889    1
# 505         505  0.04741  0.0  11.93     0  0.573  6.030  80.8  2.5050    1
#
#        TAX  PTRATIO       B  LSTAT  MEDV
# 501  273.0     21.0  391.99   9.67  22.4
# 502  273.0     21.0  396.90   9.08  20.6
# 503  273.0     21.0  396.90   5.64  23.9
# 504  273.0     21.0  393.45   6.48  22.0
# 505  273.0     21.0  396.90   7.88  11.9

# %% [markdown]
# #API - Application Programming Interface

# %%
# API - Software intermediataries to communicte between softwares

# installing the kaggle library

# !pip install kaggle

# %% [markdown]
# Upload kaggle.json file

# %%
# NOTE1 : your mail id used in google colab and kaggle should be same
# NOTE2 : first step is to join the competetion and the second step is to download the json file

# configure the path of kaggle.json file
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# import the earthquake dataset through our API

# !kaggle competitions download -c LANL-Earthquake-Prediction
# Out:
# 403 - Forbidden - You must accept this competition's rules before you'll be able to download files.

# %% [markdown]
# Right now, we cannot download the Earthquake datasets through API. This is because the competition is already over. You need a ongoing competition to download them and fetch data through API
#
#
# NOTE: When joining in such competitions, we have to access those data, for such purposes this method can be used

# %%
'''
  Extraction of Compressed Document

- These thing have to done after downloading those files
- extracting the zip file

from zipfile import ZipFile
dataset = '/content/train.csv.zip'

with ZipFile(dataset, 'r') as zip:
  zip.extractall()
  print("The dataset is extracted")
'''
# Out:
# '\n- These thing have to done after downloading those files \n- extracting the zip file \n\nfrom zipfile import ZipFile\ndataset = \'/content/train.csv.zip\'\n\nwith ZipFile(dataset, \'r\') as zip: \n  zip.extractall()\n  print("The dataset is extracted")\n'
